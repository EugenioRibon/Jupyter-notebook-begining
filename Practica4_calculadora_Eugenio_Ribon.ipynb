# %%
usos = 0
while usos != 1 :
    print ("******Calculadora iMAT******")
    print ("1. Sumar") 
    print ("2. Restar")
    print ("3. Multiplicar")
    print ("4. Dividir")
    print (" ")
    print ("5. Valor absoluto")
    print ("6. Redondeo de un número al alza")
    print ("7. Valor ASCII de un carácter")
    print ("8. Carácter de un código ASCII")
    print (" ")
    print ("9. Salir")
    print ("****************************")
    operacion = int(input("Operación:(numero del 1 al 9)"))
    
    
    if operacion <= 4:
        tipo_dato = input("Eliga el tipo de dato para la operación: (int/float/complex)")
        
        if tipo_dato == "int":
            numero1 = int(input("Numero1: "))
            numero2 = int(input("Numero2: "))
        
            
            if operacion == 1: 
                resultado = numero1 + numero2
                print (f"{numero1} + {numero2} = {resultado}")
                
            if operacion == 2:
                resultado = numero1 - numero2
                print (f"{numero1} - {numero2} = {resultado}")
            
            if operacion == 3:
                resultado = numero1 * numero2
                print (f"{numero1} * {numero2} = {resultado}")
            
            if operacion == 4:
                resultado = numero1 // numero2
                print (f"{numero1} // {numero2} = {resultado}")
                
        if tipo_dato == "float":
            numero1 = float(input("Numero1: "))
            numero2 = float(input("Numero2: "))
        
            
            if operacion == 1: 
                resultado = numero1 + numero2
                print (f"{numero1} + {numero2} = {resultado}")
                
            if operacion == 2:
                resultado = numero1 - numero2
                print (f"{numero1} - {numero2} = {resultado}")
            
            if operacion == 3:
                resultado = numero1 * numero2
                print (f"{numero1} * {numero2} = {resultado}")
            
            if operacion == 4:
                resultado = numero1 / numero2
                print (f"{numero1} / {numero2} = {resultado}")
                
        if tipo_dato == "complex":
            numero1 = complex(input("Numero1: "))
            numero2 = complex(input("Numero2: "))
        
            
            if operacion == 1: 
                resultado = numero1 + numero2
                print (f"{numero1} + {numero2} = {resultado}")
                
            if operacion == 2:
                resultado = numero1 - numero2
                print (f"{numero1} - {numero2} = {resultado}")
            
            if operacion == 3:
                resultado = numero1 * numero2
                print (f"{numero1} * {numero2} = {resultado}")
            
            if operacion == 4:
                resultado = numero1 / numero2
                print (f"{numero1} / {numero2} = {resultado}")
            
    
            
    if operacion == 5:
        numero1 = int(input("Numero: "))
        resultado = abs(numero1)
        print (f"El valor absoluto de {numero1} es {resultado}")
            
    if operacion == 6:
        numero1 = float(input("Numero: "))
        resultado = round(numero1)
        print (f"El redondeo al alza de {numero1} es {resultado}")
            
    if operacion == 7:
        numero1 = input("Introduzca un caracter: ")
        resultado = ord(numero1)
        print (f"El valor ASCII de {numero1} es {resultado}")
        
    if operacion == 8:
        numero1 = int(input("Introduzca un numero:"))
        resultado = chr(numero1)
        print (f"El caracter asociado a {numero1} es {resultado}")
        
    if operacion != (1,2,3,4,5,6,7,8):
        otra_operacion = input("¿Quieres hacer otra operacion?: ")
        print (" ")
        
        if otra_operacion == "no":
            usos = 1
            print(" ")
            print("Gracias, vuelve cuando quieras.")
# Out:
# ******Calculadora iMAT******
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dividir
#
# 5. Valor absoluto
# 6. Redondeo de un número al alza
# 7. Valor ASCII de un carácter
# 8. Carácter de un código ASCII
#
# 9. Salir
# ****************************
